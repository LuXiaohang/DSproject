# %%
# RESNETINCEPTIONV2
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(299),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(360),
        transforms.CenterCrop(299),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/inceptionresnetv2-520b38e4.pth" to /root/.torch/models/inceptionresnetv2-520b38e4.pth
# 100%|██████████| 223774246/223774246 [04:42<00:00, 791040.48it/s]
# Epoch 0/49
# ----------
# train Loss: 1.2328 Acc: 0.5993
# test Loss: 0.3316 Acc: 0.8988
#
# Epoch 1/49
# ----------
# train Loss: 0.7768 Acc: 0.7568
# test Loss: 1.0928 Acc: 0.8724
#
# Epoch 2/49
# ----------
# train Loss: 0.6605 Acc: 0.7911
# test Loss: 0.2673 Acc: 0.9332
#
# Epoch 3/49
# ----------
# train Loss: 0.5942 Acc: 0.8155
# test Loss: 0.7559 Acc: 0.9008
#
# Epoch 4/49
# ----------
# train Loss: 0.5687 Acc: 0.8223
# test Loss: 0.8740 Acc: 0.8360
#
# Epoch 5/49
# ----------
# train Loss: 0.5206 Acc: 0.8373
# test Loss: 0.3299 Acc: 0.9124
#
# Epoch 6/49
# ----------
# train Loss: 0.5007 Acc: 0.8428
# test Loss: 0.2934 Acc: 0.9268
#
# Epoch 7/49
# ----------
# train Loss: 0.3975 Acc: 0.8781
# test Loss: 0.2010 Acc: 0.9392
#
# Epoch 8/49
# ----------
# train Loss: 0.3742 Acc: 0.8828
# test Loss: 0.1799 Acc: 0.9468
#
# Epoch 9/49
# ----------
# train Loss: 0.3499 Acc: 0.8987
# test Loss: 0.1621 Acc: 0.9508
#
# Epoch 10/49
# ----------
# train Loss: 0.3400 Acc: 0.8964
# test Loss: 0.1737 Acc: 0.9472
#
# Epoch 11/49
# ----------
# train Loss: 0.3365 Acc: 0.9023
# test Loss: 0.2703 Acc: 0.9264
#
# Epoch 12/49
# ----------
# train Loss: 0.3140 Acc: 0.9065
# test Loss: 0.1450 Acc: 0.9576
#
# Epoch 13/49
# ----------
# train Loss: 0.3038 Acc: 0.9085
# test Loss: 0.1889 Acc: 0.9436
#
# Epoch 14/49
# ----------
# train Loss: 0.2945 Acc: 0.9097
# test Loss: 0.1732 Acc: 0.9496
#
# Epoch 15/49
# ----------
# train Loss: 0.2914 Acc: 0.9127
# test Loss: 0.1840 Acc: 0.9476
#
# Epoch 16/49
# ----------
# train Loss: 0.2948 Acc: 0.9080
# test Loss: 0.1381 Acc: 0.9600
#
# Epoch 17/49
# ----------
# train Loss: 0.2936 Acc: 0.9123
# test Loss: 0.1621 Acc: 0.9552
#
# Epoch 18/49
# ----------
# train Loss: 0.3047 Acc: 0.9089
# test Loss: 0.1391 Acc: 0.9616
#
# Epoch 19/49
# ----------
# train Loss: 0.2858 Acc: 0.9137
# test Loss: 0.1758 Acc: 0.9484
#
# Epoch 20/49
# ----------
# train Loss: 0.2819 Acc: 0.9156
# test Loss: 0.1666 Acc: 0.9520
#
# Epoch 21/49
# ----------
# train Loss: 0.2931 Acc: 0.9093
# test Loss: 0.1855 Acc: 0.9456
#
# Epoch 22/49
# ----------
# train Loss: 0.2756 Acc: 0.9147
# test Loss: 0.1566 Acc: 0.9548
#
# Epoch 23/49
# ----------
# train Loss: 0.3039 Acc: 0.9071
# test Loss: 0.1409 Acc: 0.9576
#
# Epoch 24/49
# ----------
# train Loss: 0.2743 Acc: 0.9156
# test Loss: 0.1714 Acc: 0.9528
#
# Epoch 25/49
# ----------
# train Loss: 0.2756 Acc: 0.9180
# test Loss: 0.1445 Acc: 0.9584
#
# Epoch 26/49
# ----------
# train Loss: 0.2736 Acc: 0.9177
# test Loss: 0.1386 Acc: 0.9600
#
# Epoch 27/49
# ----------
# train Loss: 0.2856 Acc: 0.9123
# test Loss: 0.1481 Acc: 0.9544
#
# Epoch 28/49
# ----------
# train Loss: 0.2821 Acc: 0.9139
# test Loss: 0.1421 Acc: 0.9588
#
# Epoch 29/49
# ----------
# train Loss: 0.2781 Acc: 0.9169
# test Loss: 0.1597 Acc: 0.9520
#
# Epoch 30/49
# ----------
# train Loss: 0.2977 Acc: 0.9092
# test Loss: 0.1441 Acc: 0.9572
#
# Epoch 31/49
# ----------
# train Loss: 0.2940 Acc: 0.9104
# test Loss: 0.1330 Acc: 0.9600
#
# Epoch 32/49
# ----------
# train Loss: 0.2853 Acc: 0.9139
# test Loss: 0.1706 Acc: 0.9516
#
# Epoch 33/49
# ----------
# train Loss: 0.2932 Acc: 0.9084
# test Loss: 0.1947 Acc: 0.9444
#
# Epoch 34/49
# ----------
# train Loss: 0.3001 Acc: 0.9084
# test Loss: 0.1440 Acc: 0.9596
#
# Epoch 35/49
# ----------
# train Loss: 0.2903 Acc: 0.9103
# test Loss: 0.1558 Acc: 0.9560
#
# Epoch 36/49
# ----------
# train Loss: 0.2970 Acc: 0.9127
# test Loss: 0.1362 Acc: 0.9600
#
# Epoch 37/49
# ----------
# train Loss: 0.2983 Acc: 0.9077
# test Loss: 0.1461 Acc: 0.9576
#
# Epoch 38/49
# ----------
# train Loss: 0.2891 Acc: 0.9136
# test Loss: 0.1576 Acc: 0.9556
#
# Epoch 39/49
# ----------
# train Loss: 0.3009 Acc: 0.9088
# test Loss: 0.1715 Acc: 0.9508
#
# Epoch 40/49
# ----------
# train Loss: 0.2906 Acc: 0.9112
# test Loss: 0.1459 Acc: 0.9592
#
# Epoch 41/49
# ----------
# train Loss: 0.2942 Acc: 0.9077
# test Loss: 0.1485 Acc: 0.9588
#
# Epoch 42/49
# ----------
# train Loss: 0.2864 Acc: 0.9125
# test Loss: 0.1567 Acc: 0.9548
#
# Epoch 43/49
# ----------
# train Loss: 0.2812 Acc: 0.9127
# test Loss: 0.2209 Acc: 0.9344
#
# Epoch 44/49
# ----------
# train Loss: 0.2943 Acc: 0.9093
# test Loss: 0.2095 Acc: 0.9388
#
# Epoch 45/49
# ----------
# train Loss: 0.2819 Acc: 0.9147
# test Loss: 0.1551 Acc: 0.9540
#
# Epoch 46/49
# ----------
# train Loss: 0.2914 Acc: 0.9131
# test Loss: 0.1712 Acc: 0.9504
#
# Epoch 47/49
# ----------
# train Loss: 0.2782 Acc: 0.9169
# test Loss: 0.1507 Acc: 0.9588
#
# Epoch 48/49
# ----------
# train Loss: 0.2954 Acc: 0.9077
# test Loss: 0.1383 Acc: 0.9608
#
# Epoch 49/49
# ----------
# train Loss: 0.2933 Acc: 0.9109
# test Loss: 0.1430 Acc: 0.9612
#
# Training complete in 319m 34s
# Best test Acc: 0.961600
