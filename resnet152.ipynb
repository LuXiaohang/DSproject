# %%
# RESNET152
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
# Out:
# Epoch 0/49
# ----------
# train Loss: 0.9507 Acc: 0.6875
# test Loss: 0.3164 Acc: 0.9076
#
# Epoch 1/49
# ----------
# train Loss: 0.6425 Acc: 0.7912
# test Loss: 0.2114 Acc: 0.9376
#
# Epoch 2/49
# ----------
# train Loss: 0.5338 Acc: 0.8285
# test Loss: 0.1995 Acc: 0.9408
#
# Epoch 3/49
# ----------
# train Loss: 0.4749 Acc: 0.8500
# test Loss: 0.2476 Acc: 0.9248
#
# Epoch 4/49
# ----------
# train Loss: 0.4449 Acc: 0.8585
# test Loss: 0.2011 Acc: 0.9384
#
# Epoch 5/49
# ----------
# train Loss: 0.4077 Acc: 0.8712
# test Loss: 0.2165 Acc: 0.9344
#
# Epoch 6/49
# ----------
# train Loss: 0.3729 Acc: 0.8813
# train Loss: 0.2694 Acc: 0.9160
# test Loss: 0.1508 Acc: 0.9584
#
# Epoch 8/49
# ----------
# train Loss: 0.2623 Acc: 0.9169
# test Loss: 0.1436 Acc: 0.9596
#
# Epoch 9/49
# ----------
# train Loss: 0.2133 Acc: 0.9357
# test Loss: 0.1395 Acc: 0.9612
#
# Epoch 10/49
# ----------
# train Loss: 0.2135 Acc: 0.9345
# test Loss: 0.1368 Acc: 0.9624
#
# Epoch 11/49
# ----------
# train Loss: 0.2199 Acc: 0.9300
# test Loss: 0.1336 Acc: 0.9620
#
# Epoch 12/49
# ----------
# train Loss: 0.2113 Acc: 0.9376
# test Loss: 0.1406 Acc: 0.9624
#
# Epoch 13/49
# ----------
# train Loss: 0.1980 Acc: 0.9385
# test Loss: 0.1331 Acc: 0.9640
#
# Epoch 14/49
# ----------
# train Loss: 0.2121 Acc: 0.9348
# test Loss: 0.1287 Acc: 0.9652
#
# Epoch 15/49
# ----------
# train Loss: 0.2060 Acc: 0.9359
# test Loss: 0.1306 Acc: 0.9668
#
# Epoch 16/49
# ----------
# train Loss: 0.1962 Acc: 0.9425
# test Loss: 0.1292 Acc: 0.9648
#
# Epoch 17/49
# ----------
# train Loss: 0.1911 Acc: 0.9396
# test Loss: 0.1346 Acc: 0.9648
#
# Epoch 18/49
# ----------
# train Loss: 0.2000 Acc: 0.9387
# test Loss: 0.1276 Acc: 0.9648
#
# Epoch 19/49
# ----------
# train Loss: 0.2069 Acc: 0.9357
# test Loss: 0.1233 Acc: 0.9676
#
# Epoch 20/49
# ----------
# train Loss: 0.1944 Acc: 0.9396
# test Loss: 0.1277 Acc: 0.9664
#
# Epoch 21/49
# ----------
# train Loss: 0.1983 Acc: 0.9384
# test Loss: 0.1289 Acc: 0.9664
#
# Epoch 22/49
# ----------
# train Loss: 0.1972 Acc: 0.9396
# test Loss: 0.1283 Acc: 0.9672
#
# Epoch 23/49
# ----------
# train Loss: 0.1940 Acc: 0.9411
# test Loss: 0.1282 Acc: 0.9660
#
# Epoch 24/49
# ----------
# train Loss: 0.1850 Acc: 0.9455
# test Loss: 0.1283 Acc: 0.9648
#
# Epoch 25/49
# ----------
# train Loss: 0.1859 Acc: 0.9425
# test Loss: 0.1276 Acc: 0.9660
#
# Epoch 26/49
# ----------
# train Loss: 0.1930 Acc: 0.9401
# test Loss: 0.1226 Acc: 0.9676
#
# Epoch 27/49
# ----------
# train Loss: 0.2022 Acc: 0.9367
# test Loss: 0.1232 Acc: 0.9664
#
# Epoch 28/49
# ----------
# test Loss: 0.1307 Acc: 0.9660
#
# Epoch 29/49
# ----------
# Process Process-247:
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Process Process-246:
# Process Process-248:
# Process Process-245:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 36, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 36, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 36, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# Traceback (most recent call last):
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/fastai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-92fb299a7fd2> in <module>()
#      15
#      16 model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
# ---> 17                        num_epochs=50)
#
# <ipython-input-3-eb441d79d9e0> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      33
#      34                 # zero the parameter gradients
# ---> 35                 optimizer.zero_grad()
#      36
#      37                 # forward
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/optim/optimizer.py in zero_grad(self)
#     114                 if p.grad is not None:
#     115                     if p.grad.volatile:
# --> 116                         p.grad.data.zero_()
#     117                     else:
#     118                         data = p.grad.data
#
# KeyboardInterrupt:
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 42, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 42, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torchvision/datasets/folder.py", line 122, in __getitem__
#     img = self.loader(path)
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torchvision/datasets/folder.py", line 69, in default_loader
#     return pil_loader(path)
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/torchvision/datasets/folder.py", line 52, in pil_loader
#     return img.convert('RGB')
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/PIL/Image.py", line 877, in convert
#     self.load()
#   File "/opt/conda/envs/fastai/lib/python3.6/site-packages/PIL/ImageFile.py", line 236, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt
