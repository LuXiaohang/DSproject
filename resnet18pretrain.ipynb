# %%
# RESNET18
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
# Out:
# Epoch 0/49
# ----------
# train Loss: 1.4143 Acc: 0.5564
# test Loss: 0.6167 Acc: 0.8316
#
# Epoch 1/49
# ----------
# train Loss: 0.7665 Acc: 0.7653
# test Loss: 0.4160 Acc: 0.8756
#
# Epoch 2/49
# ----------
# train Loss: 0.6198 Acc: 0.8059
# test Loss: 0.3475 Acc: 0.8952
#
# Epoch 3/49
# ----------
# train Loss: 0.5562 Acc: 0.8223
# test Loss: 0.3017 Acc: 0.9060
#
# Epoch 4/49
# ----------
# train Loss: 0.4946 Acc: 0.8460
# test Loss: 0.2825 Acc: 0.9116
#
# Epoch 5/49
# ----------
# train Loss: 0.4637 Acc: 0.8527
# test Loss: 0.2566 Acc: 0.9204
#
# Epoch 6/49
# ----------
# train Loss: 0.4202 Acc: 0.8667
# test Loss: 0.2549 Acc: 0.9164
#
# Epoch 7/49
# ----------
# train Loss: 0.3800 Acc: 0.8839
# test Loss: 0.2366 Acc: 0.9264
#
# Epoch 8/49
# ----------
# train Loss: 0.3825 Acc: 0.8813
# test Loss: 0.2320 Acc: 0.9264
#
# Epoch 9/49
# ----------
# train Loss: 0.3862 Acc: 0.8725
# test Loss: 0.2277 Acc: 0.9312
#
# Epoch 10/49
# ----------
# train Loss: 0.3758 Acc: 0.8805
# test Loss: 0.2273 Acc: 0.9308
#
# Epoch 11/49
# ----------
# train Loss: 0.3723 Acc: 0.8813
# test Loss: 0.2272 Acc: 0.9280
#
# Epoch 12/49
# ----------
# train Loss: 0.3615 Acc: 0.8885
# test Loss: 0.2275 Acc: 0.9288
#
# Epoch 13/49
# ----------
# train Loss: 0.3624 Acc: 0.8837
# test Loss: 0.2233 Acc: 0.9304
#
# Epoch 14/49
# ----------
# train Loss: 0.3555 Acc: 0.8897
# test Loss: 0.2218 Acc: 0.9308
#
# Epoch 15/49
# ----------
# train Loss: 0.3652 Acc: 0.8829
# test Loss: 0.2248 Acc: 0.9300
#
# Epoch 16/49
# ----------
# train Loss: 0.3693 Acc: 0.8851
# test Loss: 0.2235 Acc: 0.9304
#
# Epoch 17/49
# ----------
# train Loss: 0.3693 Acc: 0.8875
# test Loss: 0.2231 Acc: 0.9312
#
# Epoch 18/49
# ----------
# train Loss: 0.3647 Acc: 0.8837
# test Loss: 0.2240 Acc: 0.9308
#
# Epoch 19/49
# ----------
# train Loss: 0.3571 Acc: 0.8903
# test Loss: 0.2213 Acc: 0.9332
#
# Epoch 20/49
# ----------
# train Loss: 0.3606 Acc: 0.8847
# test Loss: 0.2233 Acc: 0.9332
#
# Epoch 21/49
# ----------
# train Loss: 0.3627 Acc: 0.8877
# test Loss: 0.2220 Acc: 0.9316
#
# Epoch 22/49
# ----------
# train Loss: 0.3574 Acc: 0.8901
# test Loss: 0.2227 Acc: 0.9308
#
# Epoch 23/49
# ----------
# train Loss: 0.3446 Acc: 0.8939
# test Loss: 0.2216 Acc: 0.9288
#
# Epoch 24/49
# ----------
# train Loss: 0.3741 Acc: 0.8780
# test Loss: 0.2226 Acc: 0.9300
#
# Epoch 25/49
# ----------
# train Loss: 0.3632 Acc: 0.8860
# test Loss: 0.2202 Acc: 0.9316
#
# Epoch 26/49
# ----------
# train Loss: 0.3516 Acc: 0.8917
# test Loss: 0.2216 Acc: 0.9312
#
# Epoch 27/49
# ----------
# train Loss: 0.3583 Acc: 0.8880
# test Loss: 0.2212 Acc: 0.9332
#
# Epoch 28/49
# ----------
# train Loss: 0.3669 Acc: 0.8849
# test Loss: 0.2227 Acc: 0.9300
#
# Epoch 29/49
# ----------
# train Loss: 0.3550 Acc: 0.8903
# test Loss: 0.2224 Acc: 0.9316
#
# Epoch 30/49
# ----------
# train Loss: 0.3580 Acc: 0.8860
# test Loss: 0.2225 Acc: 0.9316
#
# Epoch 31/49
# ----------
# train Loss: 0.3605 Acc: 0.8897
# test Loss: 0.2215 Acc: 0.9324
#
# Epoch 32/49
# ----------
# train Loss: 0.3493 Acc: 0.8917
# test Loss: 0.2210 Acc: 0.9320
#
# Epoch 33/49
# ----------
# train Loss: 0.3545 Acc: 0.8928
# test Loss: 0.2207 Acc: 0.9292
#
# Epoch 34/49
# ----------
# train Loss: 0.3500 Acc: 0.8928
# test Loss: 0.2222 Acc: 0.9304
#
# Epoch 35/49
# ----------
# train Loss: 0.3604 Acc: 0.8891
# test Loss: 0.2213 Acc: 0.9308
#
# Epoch 36/49
# ----------
# train Loss: 0.3510 Acc: 0.8893
# test Loss: 0.2225 Acc: 0.9320
#
# Epoch 37/49
# ----------
# train Loss: 0.3553 Acc: 0.8911
# test Loss: 0.2219 Acc: 0.9316
#
# Epoch 38/49
# ----------
# train Loss: 0.3684 Acc: 0.8828
# test Loss: 0.2222 Acc: 0.9332
#
# Epoch 39/49
# ----------
# train Loss: 0.3593 Acc: 0.8877
# test Loss: 0.2216 Acc: 0.9320
#
# Epoch 40/49
# ----------
# train Loss: 0.3651 Acc: 0.8841
# test Loss: 0.2239 Acc: 0.9304
#
# Epoch 41/49
# ----------
# train Loss: 0.3558 Acc: 0.8907
# test Loss: 0.2214 Acc: 0.9312
#
# Epoch 42/49
# ----------
# train Loss: 0.3532 Acc: 0.8913
# test Loss: 0.2244 Acc: 0.9304
#
# Epoch 43/49
# ----------
# train Loss: 0.3654 Acc: 0.8864
# test Loss: 0.2228 Acc: 0.9308
#
# Epoch 44/49
# ----------
# train Loss: 0.3479 Acc: 0.8913
# test Loss: 0.2242 Acc: 0.9308
#
# Epoch 45/49
# ----------
# train Loss: 0.3513 Acc: 0.8895
# test Loss: 0.2261 Acc: 0.9304
#
# Epoch 46/49
# ----------
# train Loss: 0.3549 Acc: 0.8852
# test Loss: 0.2219 Acc: 0.9316
#
# Epoch 47/49
# ----------
# train Loss: 0.3671 Acc: 0.8839
# test Loss: 0.2220 Acc: 0.9308
#
# Epoch 48/49
# ----------
# train Loss: 0.3432 Acc: 0.8916
# test Loss: 0.2228 Acc: 0.9308
#
# Epoch 49/49
# ----------
# train Loss: 0.3694 Acc: 0.8837
# test Loss: 0.2235 Acc: 0.9324
#
# Training complete in 67m 52s
# Best test Acc: 0.933200

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.max_memory_allocated(device=0)
