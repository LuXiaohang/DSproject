# %%
# RANDOM AFFINE
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        RandomAffine(10),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        RandomAffine(10),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
# Out:
# Epoch 0/49
# ----------
# train Loss: 1.4045 Acc: 0.5585
# test Loss: 0.6100 Acc: 0.8264
#
# Epoch 1/49
# ----------
# train Loss: 0.7844 Acc: 0.7585
# test Loss: 0.4204 Acc: 0.8752
#
# Epoch 2/49
# ----------
# train Loss: 0.6402 Acc: 0.7960
# test Loss: 0.3308 Acc: 0.9020
#
# Epoch 3/49
# ----------
# train Loss: 0.5541 Acc: 0.8235
# test Loss: 0.2919 Acc: 0.9076
#
# Epoch 4/49
# ----------
# train Loss: 0.5058 Acc: 0.8435
# test Loss: 0.2721 Acc: 0.9184
#
# Epoch 5/49
# ----------
# train Loss: 0.4694 Acc: 0.8529
# test Loss: 0.2495 Acc: 0.9272
#
# Epoch 6/49
# ----------
# train Loss: 0.4337 Acc: 0.8619
# test Loss: 0.2602 Acc: 0.9200
#
# Epoch 7/49
# ----------
# train Loss: 0.3986 Acc: 0.8757
# test Loss: 0.2383 Acc: 0.9272
#
# Epoch 8/49
# ----------
# train Loss: 0.4089 Acc: 0.8739
# test Loss: 0.2296 Acc: 0.9316
#
# Epoch 9/49
# ----------
# train Loss: 0.3967 Acc: 0.8689
# test Loss: 0.2271 Acc: 0.9356
#
# Epoch 10/49
# ----------
# train Loss: 0.3952 Acc: 0.8744
# test Loss: 0.2342 Acc: 0.9260
#
# Epoch 11/49
# ----------
# train Loss: 0.3883 Acc: 0.8777
# test Loss: 0.2346 Acc: 0.9324
#
# Epoch 12/49
# ----------
# train Loss: 0.3899 Acc: 0.8795
# test Loss: 0.2310 Acc: 0.9272
#
# Epoch 13/49
# ----------
# train Loss: 0.3804 Acc: 0.8796
# test Loss: 0.2246 Acc: 0.9332
#
# Epoch 14/49
# ----------
# train Loss: 0.3702 Acc: 0.8853
# test Loss: 0.2303 Acc: 0.9304
#
# Epoch 15/49
# ----------
# train Loss: 0.3803 Acc: 0.8797
# test Loss: 0.2210 Acc: 0.9332
#
# Epoch 16/49
# ----------
# train Loss: 0.3811 Acc: 0.8797
# test Loss: 0.2221 Acc: 0.9312
#
# Epoch 17/49
# ----------
# train Loss: 0.3673 Acc: 0.8843
# test Loss: 0.2248 Acc: 0.9284
#
# Epoch 18/49
# ----------
# train Loss: 0.3623 Acc: 0.8849
# test Loss: 0.2240 Acc: 0.9340
#
# Epoch 19/49
# ----------
# train Loss: 0.3728 Acc: 0.8821
# test Loss: 0.2236 Acc: 0.9320
#
# Epoch 20/49
# ----------
