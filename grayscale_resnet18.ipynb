# %%
# GRAYSCALE
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(num_output_channels=3),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Grayscale(num_output_channels=3),
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.torch/models/resnet18-5c106cde.pth
# 100%|██████████| 46827520/46827520 [00:38<00:00, 1210452.03it/s]
# Epoch 0/49
# ----------
# train Loss: 1.5996 Acc: 0.4733
# test Loss: 0.8953 Acc: 0.7296
#
# Epoch 1/49
# ----------
# train Loss: 1.0136 Acc: 0.6795
# test Loss: 0.6658 Acc: 0.7940
#
# Epoch 2/49
# ----------
# train Loss: 0.8837 Acc: 0.7193
# test Loss: 0.5699 Acc: 0.8220
#
# Epoch 3/49
# ----------
# train Loss: 0.7820 Acc: 0.7444
# test Loss: 0.5155 Acc: 0.8380
#
# Epoch 4/49
# ----------
# train Loss: 0.7135 Acc: 0.7699
# test Loss: 0.4799 Acc: 0.8500
#
# Epoch 5/49
# ----------
# train Loss: 0.6774 Acc: 0.7773
# test Loss: 0.4526 Acc: 0.8552
#
# Epoch 6/49
# ----------
# train Loss: 0.6251 Acc: 0.8008
# test Loss: 0.4329 Acc: 0.8656
#
# Epoch 7/49
# ----------
# train Loss: 0.5994 Acc: 0.8103
# test Loss: 0.4107 Acc: 0.8716
#
# Epoch 8/49
# ----------
# train Loss: 0.5795 Acc: 0.8128
# test Loss: 0.4055 Acc: 0.8760
#
# Epoch 9/49
# ----------
# train Loss: 0.5686 Acc: 0.8217
# test Loss: 0.3988 Acc: 0.8740
#
# Epoch 10/49
# ----------
# train Loss: 0.5650 Acc: 0.8179
# test Loss: 0.4003 Acc: 0.8720
#
# Epoch 11/49
# ----------
# train Loss: 0.5580 Acc: 0.8259
# test Loss: 0.3990 Acc: 0.8756
#
# Epoch 12/49
# ----------
# train Loss: 0.5581 Acc: 0.8199
# test Loss: 0.3921 Acc: 0.8740
#
# Epoch 13/49
# ----------
# train Loss: 0.5458 Acc: 0.8241
# test Loss: 0.3924 Acc: 0.8772
#
# Epoch 14/49
# ----------
# train Loss: 0.5302 Acc: 0.8327
# test Loss: 0.3901 Acc: 0.8784
#
# Epoch 15/49
# ----------
# train Loss: 0.5401 Acc: 0.8265
# test Loss: 0.3889 Acc: 0.8792
#
# Epoch 16/49
# ----------
# train Loss: 0.5578 Acc: 0.8251
# test Loss: 0.3928 Acc: 0.8760
#
# Epoch 17/49
# ----------
# train Loss: 0.5546 Acc: 0.8183
# test Loss: 0.3901 Acc: 0.8780
#
# Epoch 18/49
# ----------
# train Loss: 0.5341 Acc: 0.8291
# test Loss: 0.3963 Acc: 0.8772
#
# Epoch 19/49
# ----------
# train Loss: 0.5310 Acc: 0.8271
# test Loss: 0.3929 Acc: 0.8760
#
# Epoch 20/49
# ----------
# train Loss: 0.5573 Acc: 0.8204
# test Loss: 0.3921 Acc: 0.8780
#
# Epoch 21/49
# ----------
# train Loss: 0.5350 Acc: 0.8292
# test Loss: 0.3913 Acc: 0.8748
#
# Epoch 22/49
# ----------
# train Loss: 0.5383 Acc: 0.8273
# test Loss: 0.3914 Acc: 0.8768
#
# Epoch 23/49
# ----------
# train Loss: 0.5503 Acc: 0.8249
# test Loss: 0.3885 Acc: 0.8796
#
# Epoch 24/49
# ----------
# train Loss: 0.5476 Acc: 0.8252
# test Loss: 0.3896 Acc: 0.8780
#
# Epoch 25/49
# ----------
# train Loss: 0.5407 Acc: 0.8245
# test Loss: 0.3914 Acc: 0.8764
#
# Epoch 26/49
# ----------
# train Loss: 0.5478 Acc: 0.8261
# test Loss: 0.3913 Acc: 0.8784
#
# Epoch 27/49
# ----------
# train Loss: 0.5525 Acc: 0.8249
# test Loss: 0.3898 Acc: 0.8760
#
# Epoch 28/49
# ----------
# train Loss: 0.5373 Acc: 0.8292
# test Loss: 0.3915 Acc: 0.8756
#
# Epoch 29/49
# ----------
# train Loss: 0.5521 Acc: 0.8219
# test Loss: 0.3886 Acc: 0.8776
#
# Epoch 30/49
# ----------
# train Loss: 0.5312 Acc: 0.8329
# test Loss: 0.3878 Acc: 0.8772
#
# Epoch 31/49
# ----------
# train Loss: 0.5518 Acc: 0.8241
# test Loss: 0.3895 Acc: 0.8784
#
# Epoch 32/49
# ----------
# train Loss: 0.5465 Acc: 0.8259
# test Loss: 0.3899 Acc: 0.8784
#
# Epoch 33/49
# ----------
# train Loss: 0.5391 Acc: 0.8297
# test Loss: 0.3911 Acc: 0.8764
#
# Epoch 34/49
# ----------
# train Loss: 0.5241 Acc: 0.8309
# test Loss: 0.3884 Acc: 0.8784
#
# Epoch 35/49
# ----------
# train Loss: 0.5387 Acc: 0.8231
# test Loss: 0.3876 Acc: 0.8772
#
# Epoch 36/49
# ----------
# train Loss: 0.5418 Acc: 0.8248
# test Loss: 0.3886 Acc: 0.8772
#
# Epoch 37/49
# ----------
# train Loss: 0.5441 Acc: 0.8249
# test Loss: 0.3927 Acc: 0.8740
#
# Epoch 38/49
# ----------
# train Loss: 0.5462 Acc: 0.8221
# test Loss: 0.3888 Acc: 0.8780
#
# Epoch 39/49
# ----------
# train Loss: 0.5524 Acc: 0.8240
# test Loss: 0.3939 Acc: 0.8732
#
# Epoch 40/49
# ----------
# train Loss: 0.5454 Acc: 0.8252
# test Loss: 0.3894 Acc: 0.8768
#
# Epoch 41/49
# ----------
# train Loss: 0.5363 Acc: 0.8265
# test Loss: 0.3904 Acc: 0.8760
#
# Epoch 42/49
# ----------
# train Loss: 0.5421 Acc: 0.8245
# test Loss: 0.3913 Acc: 0.8772
#
# Epoch 43/49
# ----------
# train Loss: 0.5453 Acc: 0.8215
# test Loss: 0.3906 Acc: 0.8776
#
# Epoch 44/49
# ----------
# train Loss: 0.5398 Acc: 0.8279
# test Loss: 0.3893 Acc: 0.8784
#
# Epoch 45/49
# ----------
# train Loss: 0.5452 Acc: 0.8247
# test Loss: 0.3896 Acc: 0.8792
#
# Epoch 46/49
# ----------
# train Loss: 0.5466 Acc: 0.8277
# test Loss: 0.3914 Acc: 0.8784
#
# Epoch 47/49
# ----------
# train Loss: 0.5507 Acc: 0.8216
# test Loss: 0.3925 Acc: 0.8744
#
# Epoch 48/49
# ----------
# train Loss: 0.5480 Acc: 0.8209
# test Loss: 0.3925 Acc: 0.8752
#
# Epoch 49/49
# ----------
# train Loss: 0.5438 Acc: 0.8253
# test Loss: 0.3922 Acc: 0.8788
#
# Training complete in 33m 21s
# Best test Acc: 0.879600
